# %%
import nltk
from bs4 import BeautifulSoup
 
import urllib.request
 
response = urllib.request.urlopen('https://wiki.python.org/moin/BeginnersGuide')
 
html = response.read()

#print(html)

#extract data in a clearer way
soup = BeautifulSoup(html,features="xml")
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# BeginnersGuide - Python WikiSearch:BeginnersGuideBeginnersGuideFrontPageRecentChangesFindPageHelpContentsBeginnersGuidePageImmutable PageCommentsInfoAttachmentsMore Actions:Raw TextPrint ViewDelete Cacheclass="disabled">------------------------Check SpellingLike PagesLocal Site Mapclass="disabled">------------------------class="disabled">Rename Pageclass="disabled">Delete Pageclass="disabled">------------------------class="disabled">------------------------class="disabled">Remove Spamclass="disabled">Revert to this revisionclass="disabled">------------------------SlideShowUserLoginBeginner's Guide to PythonNew to programming? Python is free and easy to learn if you know where to start! This guide will help you to get started quickly.Chinese TranslationNew to Python?ReadBeginnersGuide/Overviewfor a short explanation of what Python is.Getting PythonNext, install the Python interpreter on your computer. This is the program that reads Python programs and carries out their instructions; you need it before you can do any Python programming. Mac OSX distributions from 10.3 (Panther) and up include a version of Python, which may be suitable for beginning despite being as much as two years out of date.  Linux distributions also frequently include Python, which is readily upgraded.There are also Python interpreter and IDE bundles available, such asThonny. Other options can be found atIntegratedDevelopmentEnvironments.There are currently two major versions of Python available: Python 2 and Python 3. ThePython2orPython3page provides advice on how to decide which one will best suit your needs.SeeBeginnersGuide/Downloadfor instructions to download the correct version of Python.At some stage, you'll want to edit and save your program code. Take a look atHowToEditPythonCodefor some advice and recommendations.Learning PythonNext, read a tutorial and try some simple experiments with your new Python interpreter.If you have never programmed before, seeBeginnersGuide/NonProgrammersfor a list of suitable tutorials.If you have previous programming experience, consultBeginnersGuide/Programmers, which lists more advanced tutorials.If English isn't your first language, you might be more comfortable with a tutorial that's been translated into your language. Consult python.org'slist of Non-English resources.Most tutorials assume that you know how to run a program on your computer. If you are using Windows and need help with this, seeHow do I Run a Program Under Windows. There are also sites that offer in-browser coding for those who want to learn Python: seeCodecademyfor general python andDataCamporDataquestfor Python for data science.Once you have read a tutorial, you can browse throughPython's online documentation. It includesa tutorialthat might come in handy,a Library Referencethat lists all of the modules that come standard with Python, andthe Language Referencefor a complete (if rather dry) explanation of Python's syntax.When you are ready to write your first program, you will need atext editoror anIDE. If you don't want to use Thonny or something more advanced, then you can useIDLE, which is bundled with Python and supportsextensions.Need Help?Need help with any of this? ReadBeginnersGuide/Helpfor mailing lists and newsgroups.Most Python books will include an introduction to the language; seeIntroductoryBooksfor suggested titles.ConsultBeginnersGuide/Examplesfor small programs and little snippets of code that can help you learn.Or, if you prefer to learn Python through listening to a lecture, you can attend a training course or even hire a trainer to come to your company. Consult thePythonEventspage to see if any training courses are scheduled in your area, and thePythonTrainingpage for a list of trainers.Teachers can join theEDU-SIG, a mailing list for discussion of Python's use in teaching at any level ranging from K-12 up to university.Complete list of Beginner's Guide pagesBeginnersGuide(PythonDocStart16DEC2010.pdf)BeginnersGuide/DownloadBegin ...

# %%
# tokenize text using split()

tokens = [t for t in text.split()]
 
print (tokens)
# Out:
# ['BeginnersGuide', '-', 'Python', 'WikiSearch:BeginnersGuideBeginnersGuideFrontPageRecentChangesFindPageHelpContentsBeginnersGuidePageImmutable', 'PageCommentsInfoAttachmentsMore', 'Actions:Raw', 'TextPrint', 'ViewDelete', 'Cacheclass="disabled">------------------------Check', 'SpellingLike', 'PagesLocal', 'Site', 'Mapclass="disabled">------------------------class="disabled">Rename', 'Pageclass="disabled">Delete', 'Pageclass="disabled">------------------------class="disabled">------------------------class="disabled">Remove', 'Spamclass="disabled">Revert', 'to', 'this', 'revisionclass="disabled">------------------------SlideShowUserLoginBeginner\'s', 'Guide', 'to', 'PythonNew', 'to', 'programming?', 'Python', 'is', 'free', 'and', 'easy', 'to', 'learn', 'if', 'you', 'know', 'where', 'to', 'start!', 'This', 'guide', 'will', 'help', 'you', 'to', 'get', 'started', 'quickly.Chinese', 'TranslationNew', 'to', 'Python?ReadBeginnersGuide/Overviewfor', 'a', 'short', 'explanation', 'of', 'what', 'Python', 'is.Getting', 'PythonNext,', 'install', 'the', 'Python', 'interpreter', 'on', 'your', 'computer.', 'This', 'is', 'the', 'program', 'that', 'reads', 'Python', 'programs', 'and', 'carries', 'out', 'their', 'instructions;', 'you', 'need', 'it', 'before', 'you', 'can', 'do', 'any', 'Python', 'programming.', 'Mac', 'OSX', 'distributions', 'from', '10.3', '(Panther)', 'and', 'up', 'include', 'a', 'version', 'of', 'Python,', 'which', 'may', 'be', 'suitable', 'for', 'beginning', 'despite', 'being', 'as', 'much', 'as', 'two', 'years', 'out', 'of', 'date.', 'Linux', 'distributions', 'also', 'frequently', 'include', 'Python,', 'which', 'is', 'readily', 'upgraded.There', 'are', 'also', 'Python', 'interpreter', 'and', 'IDE', 'bundles', 'available,', 'such', 'asThonny.', 'Other', 'options', 'can', 'be', 'found', 'atIntegratedDevelopmentEnvironments.There', 'are', 'currently', 'two', 'major', 'versions', 'of', 'Python', 'available:', 'Python', '2', 'and', 'Python', '3.', 'ThePython2orPython3page', 'provides', 'advice', 'on', 'how', 'to', 'decide', 'which', 'one', 'will', 'best', 'suit', 'your', 'needs.SeeBeginnersGuide/Downloadfor', 'instructions', 'to', 'download', 'the', 'correct', 'version', 'of', 'Python.At', 'some', 'stage,', "you'll", 'want', 'to', 'edit', 'and', 'save', 'your', 'program', 'code.', 'Take', 'a', 'look', 'atHowToEditPythonCodefor', 'some', 'advice', 'and', 'recommendations.Learning', 'PythonNext,', 'read', 'a', 'tutorial', 'and', 'try', 'some', 'simple', 'experiments', 'with', 'your', 'new', 'Python', 'interpreter.If', 'you', 'have', 'never', 'programmed', 'before,', 'seeBeginnersGuide/NonProgrammersfor', 'a', 'list', 'of', 'suitable', 'tutorials.If', 'you', 'have', 'previous', 'programming', 'experience,', 'consultBeginnersGuide/Programmers,', 'which', 'lists', 'more', 'advanced', 'tutorials.If', 'English', "isn't", 'your', 'first', 'language,', 'you', 'might', 'be', 'more', 'comfortable', 'with', 'a', 'tutorial', "that's", 'been', 'translated', 'into', 'your', 'language.', 'Consult', "python.org'slist", 'of', 'Non-English', 'resources.Most', 'tutorials', 'assume', 'that', 'you', 'know', 'how', 'to', 'run', 'a', 'program', 'on', 'your', 'computer.', 'If', 'you', 'are', 'using', 'Windows', 'and', 'need', 'help', 'with', 'this,', 'seeHow', 'do', 'I', 'Run', 'a', 'Program', 'Under', 'Windows.', 'There', 'are', 'also', 'sites', 'that', 'offer', 'in-browser', 'coding', 'for', 'those', 'who', 'want', 'to', 'learn', 'Python:', 'seeCodecademyfor', 'general', 'python', 'andDataCamporDataquestfor', 'Python', 'for', 'data', 'science.Once', 'you', 'have', 'read', 'a', 'tutorial,', 'you', 'can', 'browse', "throughPython's", 'online', 'documentation.', 'It', 'includesa', 'tutorialthat', 'might', 'come', 'in', 'handy,a', 'Library', 'Referencethat', 'lists', 'all', 'of', 'the', 'modules', 'that', 'come', 'standard', 'with', 'Python,', 'andthe', 'Language', 'Referencefor', 'a', 'complete', '(if', 'rather', 'dry)', 'explanation', 'of', "Python's",  ...

# %%
# count word frequency

freq = nltk.FreqDist(tokens)
print(freq)
#type(freq)
for key,val in freq.items():
 
    print (str(key) + ':' + str(val))
# Out:
# <FreqDist with 438 samples and 788 outcomes>
# BeginnersGuide:1
# -:2
# Python:23
# WikiSearch:BeginnersGuideBeginnersGuideFrontPageRecentChangesFindPageHelpContentsBeginnersGuidePageImmutable:1
# PageCommentsInfoAttachmentsMore:1
# Actions:Raw:1
# TextPrint:1
# ViewDelete:1
# Cacheclass="disabled">------------------------Check:1
# SpellingLike:1
# PagesLocal:1
# Site:1
# Mapclass="disabled">------------------------class="disabled">Rename:1
# Pageclass="disabled">Delete:1
# Pageclass="disabled">------------------------class="disabled">------------------------class="disabled">Remove:1
# Spamclass="disabled">Revert:1
# to:33
# this:1
# revisionclass="disabled">------------------------SlideShowUserLoginBeginner's:1
# Guide:2
# PythonNew:1
# programming?:1
# is:6
# free:1
# and:20
# easy:1
# learn:3
# if:3
# you:24
# know:2
# where:2
# start!:1
# This:2
# guide:2
# will:5
# help:4
# get:1
# started:1
# quickly.Chinese:1
# TranslationNew:1
# Python?ReadBeginnersGuide/Overviewfor:1
# a:23
# short:1
# explanation:2
# of:18
# what:1
# is.Getting:1
# PythonNext,:2
# install:1
# the:19
# interpreter:2
# on:5
# your:14
# computer.:2
# program:3
# that:6
# reads:1
# programs:2
# carries:1
# out:3
# their:1
# instructions;:1
# need:3
# it:1
# before:1
# can:10
# do:2
# any:4
# programming.:1
# Mac:1
# OSX:1
# distributions:2
# from:2
# 10.3:1
# (Panther):1
# up:2
# include:3
# version:2
# Python,:3
# which:5
# may:2
# be:3
# suitable:2
# for:9
# beginning:1
# despite:1
# being:1
# as:2
# much:1
# two:2
# years:1
# date.:1
# Linux:1
# also:4
# frequently:1
# readily:1
# upgraded.There:1
# are:7
# IDE:1
# bundles:1
# available,:1
# such:1
# asThonny.:1
# Other:1
# options:1
# found:1
# atIntegratedDevelopmentEnvironments.There:1
# currently:1
# major:1
# versions:1
# available::1
# 2:1
# 3.:1
# ThePython2orPython3page:1
# provides:1
# advice:2
# how:2
# decide:1
# one:1
# best:1
# suit:1
# needs.SeeBeginnersGuide/Downloadfor:1
# instructions:1
# download:1
# correct:1
# Python.At:1
# some:4
# stage,:1
# you'll:1
# want:3
# edit:2
# save:1
# code.:1
# Take:1
# look:2
# atHowToEditPythonCodefor:1
# recommendations.Learning:1
# read:3
# tutorial:2
# try:3
# simple:1
# experiments:1
# with:6
# new:1
# interpreter.If:1
# have:5
# never:1
# programmed:1
# before,:1
# seeBeginnersGuide/NonProgrammersfor:1
# list:4
# tutorials.If:2
# previous:1
# programming:1
# experience,:1
# consultBeginnersGuide/Programmers,:1
# lists:3
# more:5
# advanced:2
# English:1
# isn't:1
# first:3
# language,:1
# might:2
# comfortable:1
# that's:1
# been:1
# translated:1
# into:1
# language.:1
# Consult:2
# python.org'slist:1
# Non-English:1
# resources.Most:1
# tutorials:1
# assume:1
# run:1
# If:3
# using:1
# Windows:1
# this,:1
# seeHow:1
# I:1
# Run:1
# Program:1
# Under:1
# Windows.:1
# There:1
# sites:1
# offer:1
# in-browser:1
# coding:1
# those:1
# who:1
# Python::1
# seeCodecademyfor:1
# general:1
# python:5
# andDataCamporDataquestfor:1
# data:1
# science.Once:1
# tutorial,:1
# browse:1
# throughPython's:1
# online:2
# documentation.:1
# It:1
# includesa:1
# tutorialthat:1
# come:3
# in:8
# handy,a:1
# Library:1
# Referencethat:1
# all:1
# modules:1
# standard:1
# andthe:1
# Language:1
# Referencefor:1
# complete:1
# (if:1
# rather:1
# dry):1
# Python's:3
# syntax.When:1
# ready:1
# write:2
# program,:1
# atext:1
# editoror:1
# anIDE.:1
# don't:1
# use:4
# Thonny:1
# or:7
# something:2
# advanced,:1
# then:1
# useIDLE,:1
# bundled:1
# supportsextensions.Need:1
# Help?Need:1
# this?:1
# ReadBeginnersGuide/Helpfor:1
# mailing:3
# newsgroups.Most:1
# books:1
# an:2
# introduction:1
# language;:1
# seeIntroductoryBooksfor:1
# suggested:1
# titles.ConsultBeginnersGuide/Examplesfor:1
# small:1
# little:1
# snippets:1
# code:1
# learn.Or,:1
# prefer:1
# through:1
# listening:1
# lecture,:1
# attend:1
# training:2
# course:1
# even:1
# hire:1
# trainer:1
# company.:1
# thePythonEventspage:1
# see:1
# courses:1
# scheduled:1
# area,:1
# thePythonTrainingpage:1
# trainers.Teachers:1
# join:2
# theEDU-SIG,:1
# discussion:1
# teaching:1
# at:1
# level:1
# ranging:1
# K-12:1
# university.Complete:1
# Beginner's:1
# pagesBeginnersGuide(PythonDocStart16DEC2010.pdf)BeginnersGuide/DownloadBeginnersGuide/ExamplesBeginnersGuide/HelpBeginnersGuide/MathematicsBeginnersGuide/NonProgrammersBeginnersGuide/OverviewBeginnersGuide/ProgrammersBeginnersGuide/Programmers(Cpp2Python.pdf)BeginnersGuide/Programmers(Tutorial.txt)BeginnersGuide/Programmers/SimpleExamplesQuiz:1
# ExercisesCheckIO:1
# -Online:1
# learning,:1
# testing:1
# improving:1
# skillsAfter:1
# Hours:1
# Programming:1
# -Python:2
# QuizPython:2
# Guru:1
# Quiz-Python:1
# QuizPyschools:1
# -A:2
# Collection:1
# Quiz:2
# Exercise:1
# QuestionsPyGUI:1
# -Collection:1
# quiz:1
# answers,Examples:1
# And:1
# GUI:1
# Tkinter:1
# Tutorials:1
# For:1
# BeginnersPythonspot:1
# Challenge:1
# App:1
# Android:1
# PlatformCS:1
# Circles:1
# lessons:1
# graded:1
# exercisesLooking:1
# particular:1
# module:3
# application?The:1
# place:1
# thePython:5
# Package:2
# Index.If:1
# can't:1
# find:3
# anything:2
# relevant:2
# Index,trysearching:1
# python.org-:1
# mentioned:1
# site,:1
# theFAQs,:1
# newsgroup.:1
# More:1
# info:where:1
# search.You:1
# our:1
# external:1
# guest:1
# project,pydoc.net,:1
# package:1
# search.Next,:1
# tryGoogleor:1
# other:2
# search:1
# engine:1
# choice.:1
# Searching:1
# keywords:1
# usually:1
# helpful.Finally,:1
# posting:1
# query:1
# comp.lang.python:1
# Usenet:1
# group.Want:1
# contribute?Python:1
# product:1
# Software:1
# Foundation,:1
# non-profit:1
# organization:1
# holds:1
# copyright.Donations:1
# PSFare:1
# tax-deductible:1
# USA,:1
# donate:1
# via:1
# credit:1
# card:1
# orPayPal.To:1
# report:2
# bug:2
# core,:3
# Bug:1
# Tracker.To:1
# contribute:3
# fix:1
# patch:1
# Developer's:1
# Guidefor:1
# information:1
# about:1
# development:1
# process.To:1
# officialPython:1
# documentation,:1
# theDocumentation:1
# SIG,:1
# todocs@python.org,:1
# theIssue:1
# Trackerto:1
# documentation:1
# patch.To:1
# announce:1
# application:1
# community,:1
# usecomp.lang.python.announce.:1
# Seethe:1
# listsfor:1
# information.To:1
# propose:1
# changes:1
# post:1
# thoughts:1
# tocomp.lang.python.:1
# implementation,:1
# follow:1
# Patch:1
# Guidelines.If:1
# question:1
# not:1
# sure:1
# it,:1
# check:1
# theWhereDoIReportThis?page.CategoryDocumentationBeginnersGuide:1
# (last:1
# edited:1
# 2017-09-10:1
# 19:48:24:1
# bydvs1)MoinMoin:1
# PoweredPython:1
# PoweredGPL:1
# licensedValid:1
# HTML:1
# 4.01Unable:1
# page?:1
# See:1
# FrontPage:1
# instructions.:1

# %%
freq.plot(20, cumulative=False)

# %%
# removing stop words

from nltk.corpus import stopwords
 
clean_tokens = tokens[:]  # copy of the list
 
#sr = stopwords.words('english')
#print(sr) 
for token in tokens:
 
    if token in stopwords.words('english'):
 
        clean_tokens.remove(token)

newfreq = nltk.FreqDist(clean_tokens)
 
for key,val in newfreq.items():
 
    print (str(key) + ':' + str(val))
# Out:
# BeginnersGuide:1
# -:2
# Python:23
# WikiSearch:BeginnersGuideBeginnersGuideFrontPageRecentChangesFindPageHelpContentsBeginnersGuidePageImmutable:1
# PageCommentsInfoAttachmentsMore:1
# Actions:Raw:1
# TextPrint:1
# ViewDelete:1
# Cacheclass="disabled">------------------------Check:1
# SpellingLike:1
# PagesLocal:1
# Site:1
# Mapclass="disabled">------------------------class="disabled">Rename:1
# Pageclass="disabled">Delete:1
# Pageclass="disabled">------------------------class="disabled">------------------------class="disabled">Remove:1
# Spamclass="disabled">Revert:1
# revisionclass="disabled">------------------------SlideShowUserLoginBeginner's:1
# Guide:2
# PythonNew:1
# programming?:1
# free:1
# easy:1
# learn:3
# know:2
# start!:1
# This:2
# guide:2
# help:4
# get:1
# started:1
# quickly.Chinese:1
# TranslationNew:1
# Python?ReadBeginnersGuide/Overviewfor:1
# short:1
# explanation:2
# is.Getting:1
# PythonNext,:2
# install:1
# interpreter:2
# computer.:2
# program:3
# reads:1
# programs:2
# carries:1
# instructions;:1
# need:3
# programming.:1
# Mac:1
# OSX:1
# distributions:2
# 10.3:1
# (Panther):1
# include:3
# version:2
# Python,:3
# may:2
# suitable:2
# beginning:1
# despite:1
# much:1
# two:2
# years:1
# date.:1
# Linux:1
# also:4
# frequently:1
# readily:1
# upgraded.There:1
# IDE:1
# bundles:1
# available,:1
# asThonny.:1
# Other:1
# options:1
# found:1
# atIntegratedDevelopmentEnvironments.There:1
# currently:1
# major:1
# versions:1
# available::1
# 2:1
# 3.:1
# ThePython2orPython3page:1
# provides:1
# advice:2
# decide:1
# one:1
# best:1
# suit:1
# needs.SeeBeginnersGuide/Downloadfor:1
# instructions:1
# download:1
# correct:1
# Python.At:1
# stage,:1
# you'll:1
# want:3
# edit:2
# save:1
# code.:1
# Take:1
# look:2
# atHowToEditPythonCodefor:1
# recommendations.Learning:1
# read:3
# tutorial:2
# try:3
# simple:1
# experiments:1
# new:1
# interpreter.If:1
# never:1
# programmed:1
# before,:1
# seeBeginnersGuide/NonProgrammersfor:1
# list:4
# tutorials.If:2
# previous:1
# programming:1
# experience,:1
# consultBeginnersGuide/Programmers,:1
# lists:3
# advanced:2
# English:1
# isn't:1
# first:3
# language,:1
# might:2
# comfortable:1
# that's:1
# translated:1
# language.:1
# Consult:2
# python.org'slist:1
# Non-English:1
# resources.Most:1
# tutorials:1
# assume:1
# run:1
# If:3
# using:1
# Windows:1
# this,:1
# seeHow:1
# I:1
# Run:1
# Program:1
# Under:1
# Windows.:1
# There:1
# sites:1
# offer:1
# in-browser:1
# coding:1
# Python::1
# seeCodecademyfor:1
# general:1
# python:5
# andDataCamporDataquestfor:1
# data:1
# science.Once:1
# tutorial,:1
# browse:1
# throughPython's:1
# online:2
# documentation.:1
# It:1
# includesa:1
# tutorialthat:1
# come:3
# handy,a:1
# Library:1
# Referencethat:1
# modules:1
# standard:1
# andthe:1
# Language:1
# Referencefor:1
# complete:1
# (if:1
# rather:1
# dry):1
# Python's:3
# syntax.When:1
# ready:1
# write:2
# program,:1
# atext:1
# editoror:1
# anIDE.:1
# don't:1
# use:4
# Thonny:1
# something:2
# advanced,:1
# useIDLE,:1
# bundled:1
# supportsextensions.Need:1
# Help?Need:1
# this?:1
# ReadBeginnersGuide/Helpfor:1
# mailing:3
# newsgroups.Most:1
# books:1
# introduction:1
# language;:1
# seeIntroductoryBooksfor:1
# suggested:1
# titles.ConsultBeginnersGuide/Examplesfor:1
# small:1
# little:1
# snippets:1
# code:1
# learn.Or,:1
# prefer:1
# listening:1
# lecture,:1
# attend:1
# training:2
# course:1
# even:1
# hire:1
# trainer:1
# company.:1
# thePythonEventspage:1
# see:1
# courses:1
# scheduled:1
# area,:1
# thePythonTrainingpage:1
# trainers.Teachers:1
# join:2
# theEDU-SIG,:1
# discussion:1
# teaching:1
# level:1
# ranging:1
# K-12:1
# university.Complete:1
# Beginner's:1
# pagesBeginnersGuide(PythonDocStart16DEC2010.pdf)BeginnersGuide/DownloadBeginnersGuide/ExamplesBeginnersGuide/HelpBeginnersGuide/MathematicsBeginnersGuide/NonProgrammersBeginnersGuide/OverviewBeginnersGuide/ProgrammersBeginnersGuide/Programmers(Cpp2Python.pdf)BeginnersGuide/Programmers(Tutorial.txt)BeginnersGuide/Programmers/SimpleExamplesQuiz:1
# ExercisesCheckIO:1
# -Online:1
# learning,:1
# testing:1
# improving:1
# skillsAfter:1
# Hours:1
# Programming:1
# -Python:2
# QuizPython:2
# Guru:1
# Quiz-Python:1
# QuizPyschools:1
# -A:2
# Collection:1
# Quiz:2
# Exercise:1
# QuestionsPyGUI:1
# -Collection:1
# quiz:1
# answers,Examples:1
# And:1
# GUI:1
# Tkinter:1
# Tutorials:1
# For:1
# BeginnersPythonspot:1
# Challenge:1
# App:1
# Android:1
# PlatformCS:1
# Circles:1
# lessons:1
# graded:1
# exercisesLooking:1
# particular:1
# module:3
# application?The:1
# place:1
# thePython:5
# Package:2
# Index.If:1
# can't:1
# find:3
# anything:2
# relevant:2
# Index,trysearching:1
# python.org-:1
# mentioned:1
# site,:1
# theFAQs,:1
# newsgroup.:1
# More:1
# info:where:1
# search.You:1
# external:1
# guest:1
# project,pydoc.net,:1
# package:1
# search.Next,:1
# tryGoogleor:1
# search:1
# engine:1
# choice.:1
# Searching:1
# keywords:1
# usually:1
# helpful.Finally,:1
# posting:1
# query:1
# comp.lang.python:1
# Usenet:1
# group.Want:1
# contribute?Python:1
# product:1
# Software:1
# Foundation,:1
# non-profit:1
# organization:1
# holds:1
# copyright.Donations:1
# PSFare:1
# tax-deductible:1
# USA,:1
# donate:1
# via:1
# credit:1
# card:1
# orPayPal.To:1
# report:2
# bug:2
# core,:3
# Bug:1
# Tracker.To:1
# contribute:3
# fix:1
# patch:1
# Developer's:1
# Guidefor:1
# information:1
# development:1
# process.To:1
# officialPython:1
# documentation,:1
# theDocumentation:1
# SIG,:1
# todocs@python.org,:1
# theIssue:1
# Trackerto:1
# documentation:1
# patch.To:1
# announce:1
# application:1
# community,:1
# usecomp.lang.python.announce.:1
# Seethe:1
# listsfor:1
# information.To:1
# propose:1
# changes:1
# post:1
# thoughts:1
# tocomp.lang.python.:1
# implementation,:1
# follow:1
# Patch:1
# Guidelines.If:1
# question:1
# sure:1
# it,:1
# check:1
# theWhereDoIReportThis?page.CategoryDocumentationBeginnersGuide:1
# (last:1
# edited:1
# 2017-09-10:1
# 19:48:24:1
# bydvs1)MoinMoin:1
# PoweredPython:1
# PoweredGPL:1
# licensedValid:1
# HTML:1
# 4.01Unable:1
# page?:1
# See:1
# FrontPage:1
# instructions.:1

# %%
#nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
newfreq.plot(30, cumulative=False)

# %%
# tokenize sentence

from nltk.tokenize import sent_tokenize
 
mytext = "Hello Nikita, how are you? I hope everything is going well. Have a good day, see you soon."
 
print(sent_tokenize(mytext))
# Out:
# ['Hello Nikita, how are you?', 'I hope everything is going well.', 'Have a good day, see you soon.']

# %%
# tokenize words

from nltk.tokenize import word_tokenize
 
mytext = "Hello Ms. Nikita, how are you? I hope everything is going well. Have a good day, see you soon."
 
print(word_tokenize(mytext))
# Out:
# ['Hello', 'Ms.', 'Nikita', ',', 'how', 'are', 'you', '?', 'I', 'hope', 'everything', 'is', 'going', 'well', '.', 'Have', 'a', 'good', 'day', ',', 'see', 'you', 'soon', '.']

# %%
# get synonyms

from nltk.corpus import wordnet
 
syn = wordnet.synsets("science")
 
print(syn[1].definition())
 
print(syn[1].examples())
# Out:
# ability to produce solutions in some problem domain
# ['the skill of a well-trained boxer', 'the sweet science of pugilism']

# %%
# stemming
# Word stemming means removing affixes from words and return the root word

from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('beautiful'))
# Out:
# beauti

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('able'))  #does not return the correct word
# Out:
# abl

# %%
#lemmatizing

from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('increases'))
# Out:
# increase

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('brought', pos="v"))  #verb
 
print(lemmatizer.lemmatize('match', pos="n"))  #noun
 
print(lemmatizer.lemmatize('challenging', pos="a"))  #adjective
 
print(lemmatizer.lemmatize('wonderful', pos="r"))  #adverb
# Out:
# bring
# match
# challenging
# wonderful

# %%
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize

sent = "We won the match because we played well."
text= pos_tag(word_tokenize(sent), tagset='universal')
print(text)
# Out:
# [('We', 'PRON'), ('won', 'VERB'), ('the', 'DET'), ('match', 'NOUN'), ('because', 'ADP'), ('we', 'PRON'), ('played', 'VERB'), ('well', 'ADV'), ('.', '.')]

# %%
#named entity recognizer

#my_sent = "WASHINGTON -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch, the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement."
#my_sent= "In 1999, Vajpayee laid the foundation for the GoldenQuadrilateralHighway project, which would link four major cities: delhi, Mumbai, chennai and kolkata."
my_sent="“Indians is a football country now,” FIFA president Giani Infantino declared after arriving here to chair the FIFA Council meeting on Friday and attend the U-17 World Cup final."

#entity_list=nltk.ne_chunk(my_sent, binary=True)
#print(entity_list)

for sent in nltk.sent_tokenize(my_sent):
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# PERSON Giani Infantino
# ORGANIZATION FIFA Council

# %% [markdown]
# # counting no. of POS

# %%
# Import data and tagger
from nltk.corpus import twitter_samples
from nltk.tag import pos_tag_sents

# Load tokenized tweets
tweets_tokens = twitter_samples.tokenized('positive_tweets.json')
#print(tweets_tokens)

# Tag tagged tweets
tweets_tagged = pos_tag_sents(tweets_tokens)
#print(tweets_tagged)

# Set accumulators
JJ_count = 0
NN_count = 0

# Loop through list of tweets
for tweet in tweets_tagged:
    for pair in tweet:
        tag = pair[1]
        if tag == 'JJ':
            JJ_count += 1
        elif tag == 'NN':
            NN_count += 1

# Print total numbers for each adjectives and nouns
print('Total number of adjectives = ', JJ_count)
print('Total number of nouns = ', NN_count)

# %% [markdown]
# # Gender Prediction Program

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def gender_features(word): 
    return {'last_letter': word[-1]} 
 
# Load data and training 
names = ([(name, 'male') for name in names.words('male.txt')] + 
    [(name, 'female') for name in names.words('female.txt')])
 
#print(names)
featuresets = [(gender_features(n), g) for (n,g) in names] 
train_set = featuresets
classifier = nltk.NaiveBayesClassifier.train(train_set) 
 
# Predict
name = input("Name: ")
print(classifier.classify(gender_features(name)))
# Out:
# Name: Milind
# male
