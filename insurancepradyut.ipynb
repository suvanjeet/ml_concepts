# %%
import pandas as pd
import numpy as np
train= pd.read_csv(r'C:\Users\suvanjeet\Desktop\fwdassignment_pradyutparida_gameopedia\prudential-life-insurance-assessment\train.csv', sep=',', header=0, engine='python')
train.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
# 3   7               1             D4              10        0.487179
# 4   8               1             D2              26        0.230769
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               1               1  0.641791  0.581818
# 1               2               3               1  0.059701  0.600000
# 2               2               3               1  0.029851  0.745455
# 3               2               3               1  0.164179  0.672727
# 4               2               3               1  0.417910  0.654545
#
#      ...     Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print(train.shape)
# Out:
# (59381, 128)

# %%
train.describe()
# Out:
#                  Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# count  59381.000000    59381.000000    59381.000000    59381.000000
# mean   39507.211515        1.026355       24.415655        0.328952
# std    22815.883089        0.160191        5.072885        0.282562
# min        2.000000        1.000000        1.000000        0.000000
# 25%    19780.000000        1.000000       26.000000        0.076923
# 50%    39487.000000        1.000000       26.000000        0.230769
# 75%    59211.000000        1.000000       26.000000        0.487179
# max    79146.000000        2.000000       38.000000        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7       Ins_Age  \
# count    59381.000000    59381.000000    59381.000000  59381.000000
# mean         2.006955        2.673599        1.043583      0.405567
# std          0.083107        0.739103        0.291949      0.197190
# min          2.000000        1.000000        1.000000      0.000000
# ...

# %%
train.isnull().any()
# Out:
# Id                     False
# Product_Info_1         False
# Product_Info_2         False
# Product_Info_3         False
# Product_Info_4         False
# Product_Info_5         False
# Product_Info_6         False
# Product_Info_7         False
# Ins_Age                False
# Ht                     False
# Wt                     False
# BMI                    False
# Employment_Info_1       True
# Employment_Info_2      False
# Employment_Info_3      False
# Employment_Info_4       True
# Employment_Info_5      False
# Employment_Info_6       True
# InsuredInfo_1          False
# InsuredInfo_2          False
# InsuredInfo_3          False
# InsuredInfo_4          False
# InsuredInfo_5          False
# InsuredInfo_6          False
# InsuredInfo_7          False
# Insurance_History_1    False
# Insurance_History_2    False
# Insurance_History_3    False
# Insurance_History_4    False
# Insurance_History_5     True
# Insurance_History_7    False
# Insurance_History_8    False
# ...

# %%
train.info()
train.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB
# Id                         0
# Product_Info_1             0
# Product_Info_2             0
# Product_Info_3             0
# Product_Info_4             0
# Product_Info_5             0
# Product_Info_6             0
# Product_Info_7             0
# Ins_Age                    0
# Ht                         0
# Wt                         0
# BMI                        0
# Employment_Info_1         19
# Employment_Info_2          0
# Employment_Info_3          0
# Employment_Info_4       6779
# Employment_Info_5          0
# Employment_Info_6      10854
# InsuredInfo_1              0
# InsuredInfo_2              0
# InsuredInfo_3              0
# InsuredInfo_4              0
# InsuredInfo_5              0
# InsuredInfo_6              0
# InsuredInfo_7              0
# Insurance_History_1        0
# ...

# %%
per_miss = train.isnull().sum()/len(train)
print(per_miss)
# Out:
# Id                     0.000000
# Product_Info_1         0.000000
# Product_Info_2         0.000000
# Product_Info_3         0.000000
# Product_Info_4         0.000000
# Product_Info_5         0.000000
# Product_Info_6         0.000000
# Product_Info_7         0.000000
# Ins_Age                0.000000
# Ht                     0.000000
# Wt                     0.000000
# BMI                    0.000000
# Employment_Info_1      0.000320
# Employment_Info_2      0.000000
# Employment_Info_3      0.000000
# Employment_Info_4      0.114161
# Employment_Info_5      0.000000
# Employment_Info_6      0.182786
# InsuredInfo_1          0.000000
# InsuredInfo_2          0.000000
# InsuredInfo_3          0.000000
# InsuredInfo_4          0.000000
# InsuredInfo_5          0.000000
# InsuredInfo_6          0.000000
# InsuredInfo_7          0.000000
# Insurance_History_1    0.000000
# Insurance_History_2    0.000000
# Insurance_History_3    0.000000
# Insurance_History_4    0.000000
# ...

# %%
missing_features = per_miss[per_miss > 0.45].index
print(missing_features)
train1 = train.drop(missing_features, axis=1)
train1.shape
# Out:
# Index(['Family_Hist_2', 'Family_Hist_3', 'Family_Hist_5', 'Medical_History_10',
#        'Medical_History_15', 'Medical_History_24', 'Medical_History_32'],
#       dtype='object')
# (59381, 121)

# %%
test= pd.read_csv(r'C:\Users\suvanjeet\Desktop\fwdassignment_pradyutparida_gameopedia\prudential-life-insurance-assessment\test.csv', sep=',', header=0, engine='python')
test.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   1               1             D3              26        0.487179
# 1   3               1             A2              26        0.076923
# 2   4               1             D3              26        0.144667
# 3   9               1             A1              26        0.151709
# 4  12               1             A1              26        0.076923
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               3               1  0.611940  0.781818
# 1               2               3               1  0.626866  0.727273
# 2               2               3               1  0.582090  0.709091
# 3               2               1               1  0.522388  0.654545
# 4               2               3               1  0.298507  0.672727
#
#           ...          Medical_Keyword_39  Medical_Keyword_40  \
# 0         ...                           0                   0
# ...

# %%
test.isnull().any()
# Out:
# Id                     False
# Product_Info_1         False
# Product_Info_2         False
# Product_Info_3         False
# Product_Info_4         False
# Product_Info_5         False
# Product_Info_6         False
# Product_Info_7         False
# Ins_Age                False
# Ht                     False
# Wt                     False
# BMI                    False
# Employment_Info_1       True
# Employment_Info_2      False
# Employment_Info_3      False
# Employment_Info_4       True
# Employment_Info_5      False
# Employment_Info_6       True
# InsuredInfo_1          False
# InsuredInfo_2          False
# InsuredInfo_3          False
# InsuredInfo_4          False
# InsuredInfo_5          False
# InsuredInfo_6          False
# InsuredInfo_7          False
# Insurance_History_1    False
# Insurance_History_2    False
# Insurance_History_3    False
# Insurance_History_4    False
# Insurance_History_5     True
# Insurance_History_7    False
# Insurance_History_8    False
# ...

# %%
test.shape
# Out:
# (19765, 127)

# %%
test.isnull().sum()
# Out:
# Id                         0
# Product_Info_1             0
# Product_Info_2             0
# Product_Info_3             0
# Product_Info_4             0
# Product_Info_5             0
# Product_Info_6             0
# Product_Info_7             0
# Ins_Age                    0
# Ht                         0
# Wt                         0
# BMI                        0
# Employment_Info_1          3
# Employment_Info_2          0
# Employment_Info_3          0
# Employment_Info_4       2137
# Employment_Info_5          0
# Employment_Info_6       3787
# InsuredInfo_1              0
# InsuredInfo_2              0
# InsuredInfo_3              0
# InsuredInfo_4              0
# InsuredInfo_5              0
# InsuredInfo_6              0
# InsuredInfo_7              0
# Insurance_History_1        0
# Insurance_History_2        0
# Insurance_History_3        0
# Insurance_History_4        0
# Insurance_History_5     8105
# Insurance_History_7        0
# Insurance_History_8        0
# ...

# %%
per_miss1 = test.isnull().sum()/len(test)
print(per_miss1)
# Out:
# Id                     0.000000
# Product_Info_1         0.000000
# Product_Info_2         0.000000
# Product_Info_3         0.000000
# Product_Info_4         0.000000
# Product_Info_5         0.000000
# Product_Info_6         0.000000
# Product_Info_7         0.000000
# Ins_Age                0.000000
# Ht                     0.000000
# Wt                     0.000000
# BMI                    0.000000
# Employment_Info_1      0.000152
# Employment_Info_2      0.000000
# Employment_Info_3      0.000000
# Employment_Info_4      0.108120
# Employment_Info_5      0.000000
# Employment_Info_6      0.191601
# InsuredInfo_1          0.000000
# InsuredInfo_2          0.000000
# InsuredInfo_3          0.000000
# InsuredInfo_4          0.000000
# InsuredInfo_5          0.000000
# InsuredInfo_6          0.000000
# InsuredInfo_7          0.000000
# Insurance_History_1    0.000000
# Insurance_History_2    0.000000
# Insurance_History_3    0.000000
# Insurance_History_4    0.000000
# ...

# %%
missing_features1 = per_miss1[per_miss1 > 0.45].index
print(missing_features)
# Out:
# Index(['Family_Hist_2', 'Family_Hist_3', 'Family_Hist_5', 'Medical_History_10',
#        'Medical_History_15', 'Medical_History_24', 'Medical_History_32'],
#       dtype='object')

# %%
test1 = test.drop(missing_features1, axis=1)
print(test1.shape)
# Out:
# (19765, 120)

# %%
per_miss3 = test1.isnull().sum()/len(test1)
print(per_miss3)
# Out:
# Id                     0.000000
# Product_Info_1         0.000000
# Product_Info_2         0.000000
# Product_Info_3         0.000000
# Product_Info_4         0.000000
# Product_Info_5         0.000000
# Product_Info_6         0.000000
# Product_Info_7         0.000000
# Ins_Age                0.000000
# Ht                     0.000000
# Wt                     0.000000
# BMI                    0.000000
# Employment_Info_1      0.000152
# Employment_Info_2      0.000000
# Employment_Info_3      0.000000
# Employment_Info_4      0.108120
# Employment_Info_5      0.000000
# Employment_Info_6      0.191601
# InsuredInfo_1          0.000000
# InsuredInfo_2          0.000000
# InsuredInfo_3          0.000000
# InsuredInfo_4          0.000000
# InsuredInfo_5          0.000000
# InsuredInfo_6          0.000000
# InsuredInfo_7          0.000000
# Insurance_History_1    0.000000
# Insurance_History_2    0.000000
# Insurance_History_3    0.000000
# Insurance_History_4    0.000000
# ...

# %%
nulltreattrain = per_miss3[per_miss3 > 0].index
nulltreattrain
# Out:
# Index(['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6',
#        'Insurance_History_5', 'Family_Hist_4', 'Medical_History_1'],
#       dtype='object')

# %%
per_miss4 = train1.isnull().sum()/len(train1)
print(per_miss4)
# Out:
# Id                     0.000000
# Product_Info_1         0.000000
# Product_Info_2         0.000000
# Product_Info_3         0.000000
# Product_Info_4         0.000000
# Product_Info_5         0.000000
# Product_Info_6         0.000000
# Product_Info_7         0.000000
# Ins_Age                0.000000
# Ht                     0.000000
# Wt                     0.000000
# BMI                    0.000000
# Employment_Info_1      0.000320
# Employment_Info_2      0.000000
# Employment_Info_3      0.000000
# Employment_Info_4      0.114161
# Employment_Info_5      0.000000
# Employment_Info_6      0.182786
# InsuredInfo_1          0.000000
# InsuredInfo_2          0.000000
# InsuredInfo_3          0.000000
# InsuredInfo_4          0.000000
# InsuredInfo_5          0.000000
# InsuredInfo_6          0.000000
# InsuredInfo_7          0.000000
# Insurance_History_1    0.000000
# Insurance_History_2    0.000000
# Insurance_History_3    0.000000
# Insurance_History_4    0.000000
# ...

# %%
nulltreattest = per_miss4[per_miss4 > 0].index
nulltreattest
# Out:
# Index(['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6',
#        'Insurance_History_5', 'Family_Hist_4', 'Medical_History_1'],
#       dtype='object')

# %%
train1

# %%
train1['Employment_Info_1']
# Out:
# 0        0.028000
# 1        0.000000
# 2        0.030000
# 3        0.042000
# 4        0.027000
# 5        0.325000
# 6        0.110000
# 7        0.120000
# 8        0.165000
# 9        0.025000
# 10       0.050000
# 11       0.090000
# 12       0.075000
# 13       0.100000
# 14       0.160000
# 15       0.075000
# 16       0.100000
# 17       0.037800
# 18       0.080000
# 19       0.055000
# 20       0.083000
# 21       0.210000
# 22       0.031000
# 23       0.065000
# 24       0.027000
# 25       0.100000
# 26       0.150000
# 27       0.042000
# 28       0.120000
# 29       0.115000
# 30       0.075000
# 31       0.050000
# 32       0.057000
# 33       0.175000
# 34       0.110000
# 35       0.000000
# 36       0.007000
# 37       0.100000
# 38       0.050000
# 39       0.070000
# 40       0.600000
# 41       0.060000
# 42       0.020160
# 43       0.080000
# 44       0.000000
# 45       0.055000
# 46       0.065000
# 47       0.069000
# 48       0.035000
# 49       0.020000
# ...
